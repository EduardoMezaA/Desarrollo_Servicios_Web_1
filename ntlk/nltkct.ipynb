# %%
import nltk

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %% [markdown]
# # Tokenizar Texto

# %%
# LEER TEXTO DESDE URL

from bs4 import BeautifulSoup
 
import urllib.request
  
response = urllib.request.urlopen('https://diego.com.es/codigos-de-estado-http') #Obtiene el contenido HTML de la página web http://librefinanciero.com/
 
html = response.read()
 
soup = BeautifulSoup(html,"html5lib") # Limpia el texto HTML capturado
 
text = soup.get_text(strip=True)
 
print (text)
# Out:
# hljs.initHighlightingOnLoad();Códigos de estado HTTP(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#                             (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#                         m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#                 })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#                 ga('create', 'UA-62157855-1', 'auto');
#                 ga('send', 'pageview');Diego LázaroAngularLibro de PHPInicioAngularDiego LázaroContactoAngularLibro de PHPCódigos de estado HTTPCódigos de estado en las respuestas HTTP que un servidor puede devolver cuando recibe una petición HTTP requestContenido modificableSi ves errores o quieres modificar/añadir contenidos, puedescrear un pull request. GraciasLos códigos de estado HTTP describen de forma abreviada larespuesta HTTP. Estos códigos están especificados por elRFC 2616.El primer dígito del código de estado especifica uno de los5 tipos de respuesta, el mínimo para que un cliente pueda trabajar conHTTPes que reconozca estas 5 clases. LaInternet Assigned Numbers Authority(IANA) mantiene el registro oficial de códigos de estado HTTP.Indice de contenido1XX Respuestas informativas2XX Peticiones correctas3XX Redirecciones4XX Errores del cliente5XX Errores de servidor1. 1XX Respuestas informativasEste tipo de código de estado indica unarespuesta provisional. HTTP/1.0 no definió ningún estado 1XX, por lo que los servidores no deberían enviar una respuesta 1XX a un cliente HTTP/1.0 salvo para experimentos.100 Continue. El servidor ha recibido losheaders del requesty el cliente debería proceder a enviar el cuerpo de la respuesta.101 Switching Protocols. Elrequesterha solicitado al servidor conmutar protocolos.102 Processing (WebDAV; RFC 2518). Usado enrequestspara reanudar peticiones PUT o POST abortadas.2. 2XX Peticiones correctasEste código de estado indica que la acción solicitada por elclienteha sido recibida, entendida, aceptada y procesada correctamente.200 OK. El request es correcto. Esta es la respuesta estándar para respuestas correctas.201 Created. El request se ha completado y se ha creado un nuevo recurso.202 Aceptada. El request se ha aceptado para procesarlo, pero el proceso aún no ha terminado.203 Non-Authoritative Information. El request se ha procesado correctamente, pero devuelve información que podría venir de otra fuente.204 No Content. El request se ha procesado correctamente, pero no devuelve ningún contenido.205 Reset Content. El request se ha procesado correctamente, pero no devuelve ningún contenido y se requiere que el requester recargue el contenido.206 Partial Content. El servidor devuelve sólo parte del recurso debido a una limitación que ha configurado el cliente (se usa en herramientas de descarga comowget).207 Multi-Status (WebDAV; RFC 4918). El cuerpo del mensaje es XML y puede contener un número de códigos de estado diferentes dependiendo del número de sub-requests.3. 3XX RedireccionesEl cliente ha de tomar una acción adicional para completar elrequest. Muchos de estos estados se utilizan pararedirecciones. Eluser-agentpuede llevar a cabo la acción adicional sin necesidad de que actúe elusuariosólo si elmétodoutilizado en la segunda petición esGEToHEAD. Un user-agent no debería redireccionar automáticamente un request más de cinco veces, ya que esas redirecciones suelen indicar uninfinite loop.300 Multiple Choices. Es una lista de enlaces. El usuario puede seleccionar un enlace e ir a esa dirección. Hay un máximo de cinco direcciones.301 Moved Permanently. La página solicitada se ha movido permanentemente a una nueva URI.302 Found. La página solicitada se ha movido temporalmente a una nueva URI.303 See Other. La página solicitada se puede encontrar en una URI diferente.304 Not Modified. Indica que la página solicitada no se ha modificado desde la última petición.305 Use Proxy (desde HTTP/1.1). El recurso solicitado sólo está disponible a través de proxy, cuya dirección se proporciona en la respuesta. Muchos clientes HTTP como Mozilla o Internet Explorer no manejan bien estas respuestas con estos códigos de estado, sobre todo por seguridad.307 Temporary Redirect (desde HTTP/1.1). La página solicitada se ha movido temporalmente a otra URL. En este caso el recurso debería de repetirse con otra URI, sin embargo, futuros requests deberán usar la URI original. Al contrario que con la 302, el mét ...

# %%
#Crear tokens por palabras
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text,"spanish")
tokens=[word.lower() for word in tokens if word.isalpha()] # Remover los signos de puntuación
print(tokens)
# Out:
# ['códigos', 'de', 'estado', 'http', 'function', 'i', 's', 'o', 'g', 'r', 'a', 'm', 'i', 'i', 'r', 'r', 'i', 'r', 'r', 'arguments', 'i', 'r', 'new', 'date', 'o', 'o', 'a', 'm', 'window', 'document', 'ga', 'ga', 'diego', 'lázaroangularlibro', 'de', 'phpinicioangulardiego', 'lázarocontactoangularlibro', 'de', 'phpcódigos', 'de', 'estado', 'httpcódigos', 'de', 'estado', 'en', 'las', 'respuestas', 'http', 'que', 'un', 'servidor', 'puede', 'devolver', 'cuando', 'recibe', 'una', 'petición', 'http', 'requestcontenido', 'modificablesi', 'ves', 'errores', 'o', 'quieres', 'contenidos', 'puedescrear', 'un', 'pull', 'request', 'graciaslos', 'códigos', 'de', 'estado', 'http', 'describen', 'de', 'forma', 'abreviada', 'larespuesta', 'http', 'estos', 'códigos', 'están', 'especificados', 'por', 'elrfc', 'primer', 'dígito', 'del', 'código', 'de', 'estado', 'especifica', 'uno', 'de', 'tipos', 'de', 'respuesta', 'el', 'mínimo', 'para', 'que', 'un', 'cliente', 'pueda', 'trabajar', 'conhttpes', 'que', 'reconozca', 'estas', 'clases', 'lainternet', 'assigned', 'numbers', 'authority', 'iana', 'mantiene', 'el', 'registro', 'oficial', 'de', 'códigos', 'de', 'estado', 'de', 'respuestas', 'peticiones', 'errores', 'del', 'errores', 'de', 'respuestas', 'informativaseste', 'tipo', 'de', 'código', 'de', 'estado', 'indica', 'unarespuesta', 'provisional', 'no', 'definió', 'ningún', 'estado', 'por', 'lo', 'que', 'los', 'servidores', 'no', 'deberían', 'enviar', 'una', 'respuesta', 'a', 'un', 'cliente', 'salvo', 'para', 'continue', 'el', 'servidor', 'ha', 'recibido', 'losheaders', 'del', 'requesty', 'el', 'cliente', 'debería', 'proceder', 'a', 'enviar', 'el', 'cuerpo', 'de', 'la', 'switching', 'protocols', 'elrequesterha', 'solicitado', 'al', 'servidor', 'conmutar', 'processing', 'webdav', 'rfc', 'usado', 'enrequestspara', 'reanudar', 'peticiones', 'put', 'o', 'post', 'peticiones', 'correctaseste', 'código', 'de', 'estado', 'indica', 'que', 'la', 'acción', 'solicitada', 'por', 'elclienteha', 'sido', 'recibida', 'entendida', 'aceptada', 'y', 'procesada', 'ok', 'el', 'request', 'es', 'correcto', 'esta', 'es', 'la', 'respuesta', 'estándar', 'para', 'respuestas', 'created', 'el', 'request', 'se', 'ha', 'completado', 'y', 'se', 'ha', 'creado', 'un', 'nuevo', 'aceptada', 'el', 'request', 'se', 'ha', 'aceptado', 'para', 'procesarlo', 'pero', 'el', 'proceso', 'aún', 'no', 'ha', 'information', 'el', 'request', 'se', 'ha', 'procesado', 'correctamente', 'pero', 'devuelve', 'información', 'que', 'podría', 'venir', 'de', 'otra', 'no', 'content', 'el', 'request', 'se', 'ha', 'procesado', 'correctamente', 'pero', 'no', 'devuelve', 'ningún', 'reset', 'content', 'el', 'request', 'se', 'ha', 'procesado', 'correctamente', 'pero', 'no', 'devuelve', 'ningún', 'contenido', 'y', 'se', 'requiere', 'que', 'el', 'requester', 'recargue', 'el', 'partial', 'content', 'el', 'servidor', 'devuelve', 'sólo', 'parte', 'del', 'recurso', 'debido', 'a', 'una', 'limitación', 'que', 'ha', 'configurado', 'el', 'cliente', 'se', 'usa', 'en', 'herramientas', 'de', 'descarga', 'comowget', 'webdav', 'rfc', 'el', 'cuerpo', 'del', 'mensaje', 'es', 'xml', 'y', 'puede', 'contener', 'un', 'número', 'de', 'códigos', 'de', 'estado', 'diferentes', 'dependiendo', 'del', 'número', 'de', 'redireccionesel', 'cliente', 'ha', 'de', 'tomar', 'una', 'acción', 'adicional', 'para', 'completar', 'elrequest', 'muchos', 'de', 'estos', 'estados', 'se', 'utilizan', 'pararedirecciones', 'llevar', 'a', 'cabo', 'la', 'acción', 'adicional', 'sin', 'necesidad', 'de', 'que', 'actúe', 'elusuariosólo', 'si', 'elmétodoutilizado', 'en', 'la', 'segunda', 'petición', 'esgetohead', 'un', 'no', 'debería', 'redireccionar', 'automáticamente', 'un', 'request', 'más', 'de', 'cinco', 'veces', 'ya', 'que', 'esas', 'redirecciones', 'suelen', 'indicar', 'uninfinite', 'multiple', 'choices', 'es', 'una', 'lista', 'de', 'enlaces', 'el', 'usuario', 'puede', 'seleccionar', 'un', 'enlace', 'e', 'ir', 'a', 'esa', 'dirección', 'hay', 'un', 'máximo', 'de', 'cinc ...

# %%
#Verificar frecuencia de palabras 
freq = nltk.FreqDist(tokens)
for key,val in freq.items():
    print (str(key) + ':' + str(val))
# Out:
# códigos:8
# de:45
# estado:12
# http:9
# function:1
# i:6
# s:1
# o:12
# g:1
# r:6
# a:20
# m:2
# arguments:1
# new:1
# date:1
# window:1
# document:1
# ga:2
# diego:2
# lázaroangularlibro:1
# phpinicioangulardiego:1
# lázarocontactoangularlibro:1
# phpcódigos:1
# httpcódigos:1
# en:16
# las:2
# respuestas:5
# que:25
# un:16
# servidor:22
# puede:9
# devolver:1
# cuando:8
# recibe:1
# una:20
# petición:2
# requestcontenido:1
# modificablesi:1
# ves:1
# errores:5
# quieres:1
# contenidos:1
# puedescrear:1
# pull:1
# request:27
# graciaslos:1
# describen:1
# forma:1
# abreviada:1
# larespuesta:1
# estos:4
# están:1
# especificados:1
# por:10
# elrfc:1
# primer:1
# dígito:1
# del:20
# código:5
# ['códigos', 'http', 'function', 'i', 's', 'g', 'r', 'm', 'i', 'i', 'r', 'r', 'i', 'r', 'r', 'arguments', 'i', 'r', 'new', 'date', 'm', 'window', 'document', 'ga', 'ga', 'diego', 'lázaroangularlibro', 'phpinicioangulardiego', 'lázarocontactoangularlibro', 'phpcódigos', 'httpcódigos', 'respuestas', 'http', 'servidor', 'puede', 'devolver', 'recibe', 'petición', 'http', 'requestcontenido', 'modificablesi', 'ves', 'errores', 'quieres', 'contenidos', 'puedescrear', 'pull', 'request', 'graciaslos', 'códigos', 'http', 'describen', 'forma', 'abreviada', 'larespuesta', 'http', 'códigos', 'especificados', 'elrfc', 'primer', 'dígito', 'código', 'especifica', 'tipos', 'respuesta', 'mínimo', 'cliente', 'pueda', 'trabajar', 'conhttpes', 'reconozca', 'clases', 'lainternet', 'assigned', 'numbers', 'authority', 'iana', 'mantiene', 'registro', 'oficial', 'códigos', 'respuestas', 'peticiones', 'errores', 'errores', 'respuestas', 'informativaseste', 'tipo', 'código', 'indica', 'unarespuesta', 'provisional', 'definió', 'ningún', 'servidores', 'deberían', 'enviar', 'respuesta', 'cliente', 'salvo', 'continue', 'servidor', 'recibido', 'losheaders', 'requesty', 'cliente', 'debería', 'proceder', 'enviar', 'cuerpo', 'switching', 'protocols', 'elrequesterha', 'solicitado', 'servidor', 'conmutar', 'processing', 'webdav', 'rfc', 'usado', 'enrequestspara', 'reanudar', 'peticiones', 'put', 'post', 'peticiones', 'correctaseste', 'código', 'indica', 'acción', 'solicitada', 'elclienteha', 'sido', 'recibida', 'entendida', 'aceptada', 'procesada', 'ok', 'request', 'correcto', 'respuesta', 'estándar', 'respuestas', 'created', 'request', 'completado', 'creado', 'nuevo', 'aceptada', 'request', 'aceptado', 'procesarlo', 'proceso', 'aún', 'information', 'request', 'procesado', 'correctamente', 'devuelve', 'información', 'podría', 'venir', 'content', 'request', 'procesado', 'correctamente', 'devuelve', 'ningún', 'reset', 'content', 'request', 'procesado', 'correctamente', 'devuelve', 'ningún', 'contenido', 'requiere', 'requester', 'recargue', 'partial', 'content', 'servidor', 'devuelve', 'sólo', 'parte', 'recurso', 'debido', 'limitación', 'configurado', 'cliente', 'usa', 'herramientas', 'descarga', 'comowget', 'webdav', 'rfc', 'cuerpo', 'mensaje', 'xml', 'puede', 'contener', 'número', 'códigos', 'diferentes', 'dependiendo', 'número', 'redireccionesel', 'cliente', 'tomar', 'acción', 'adicional', 'completar', 'elrequest', 'utilizan', 'pararedirecciones', 'llevar', 'cabo', 'acción', 'adicional', 'necesidad', 'actúe', 'elusuariosólo', 'si', 'elmétodoutilizado', 'segunda', 'petición', 'esgetohead', 'debería', 'redireccionar', 'automáticamente', 'request', 'cinco', 'veces', 'redirecciones', 'suelen', 'indicar', 'uninfinite', 'multiple', 'choices', 'lista', 'enlaces', 'usuario', 'puede', 'seleccionar', 'enlace', 'ir', 'dirección', 'máximo', 'cinco', 'moved', 'permanently', 'página', 'solicitada', 'movido', 'permanentemente', 'nueva', 'found', 'página', 'solicitada', 'movido', 'temporalmente', 'nueva', 'see', 'other', 'página', 'solicitada', 'puede', 'encontrar', 'uri', 'not', 'modified', 'indica', 'página', 'solicitada', 'modificado', 'última', 'use', 'proxy', 'recurso', 'solicitado', 'sólo', 'disponible', 'través', 'proxy', 'cuya', 'dirección', 'proporciona', 'respuesta', 'clientes', 'http', 'mozilla', 'internet', 'explorer', 'manejan', 'bien', 'respuestas', 'códigos', 'temporary', 'redirect', 'página', 'solicitada', 'movido', 'temporalmente', 'url', 'caso', 'recurso', 'debería', 'repetirse', 'uri', 'embargo', 'futuros', 'requests', 'deberán', 'usar', 'uri', 'original', 'contrario', 'método', 'request', 'puede', 'cambiar', 'reubique', 'request', 'permanent', 'redirect', 'rfc', 'request', 'futuros', 'requests', 'deberían', 'repetirse', 'usando', 'uri', 'similar', 'permite', 'método', 'http', 'errores', 'clienteexcepto', 'responde', 'unhead', 'request', 'servidor', 'debe', 'incluir', 'entidad', 'contiene', 'explicación', 'error', 'si', 'temporal', 'permanente', 'aplicables', 'c ...

# %%
#Verificar frecuencia de palabras 
freq_clean = nltk.FreqDist(clean_tokens)
for key,val in freq_clean.items():
    print (str(key) + ':' + str(val))
# Out:
# códigos:8
# http:9
# function:1
# i:6
# s:1
# g:1
# r:6
# m:2
# arguments:1
# new:1
# date:1
# window:1
# document:1
# ga:2
# diego:2
# lázaroangularlibro:1
# phpinicioangulardiego:1
# lázarocontactoangularlibro:1
# phpcódigos:1
# httpcódigos:1
# respuestas:5
# servidor:22
# puede:9
# devolver:1
# recibe:1
# petición:2
# requestcontenido:1
# modificablesi:1
# ves:1
# errores:5
# quieres:1
# contenidos:1
# puedescrear:1
# pull:1
# request:27
# graciaslos:1
# describen:1
# forma:1
# abreviada:1
# larespuesta:1
# especificados:1
# elrfc:1
# primer:1
# dígito:1
# código:5
# especifica:2
# tipos:1
# respuesta:7
# mínimo:1
# cliente:10
# pueda:1
# trabajar:1
# conhttpes:1
# reconozca:1
# clases:1
# lainternet:1
# assigned:1
# numbers:1
# authority:1
# iana:1
# mantiene:1
# registro:1
# oficial:1
# peticiones:3
# informativaseste:1
# tipo:1
# indica:4
# unarespuesta:1
# provisional:1
# definió:1
# ningún:3
# servidores:2
# deberían:2
# enviar:2
# salvo:2
# continue:1
# recibido:1
# losheaders:1
# requesty:1
# debería:4
# proceder:1
# cuerpo:2
# switching:1
# protocols:1
# elrequesterha:1
# solicitado:5
# conmutar:1
# processing:1
# webdav:2
# rfc:10
# usado:1
# enrequestspara:1
# reanudar:1
# put:1
# post:3
# correctaseste:1
# acción:3
# solicitada:6
# elclienteha:1
# sido:1
# recibida:1
# entendida:1
# aceptada:2
# procesada:1
# ok:1
# correcto:1
# estándar:1
# created:1
# completado:1
# creado:1
# nuevo:1
# aceptado:1
# procesarlo:1
# proceso:1
# aún:1
# information:1
# procesado:3
# correctamente:3
# devuelve:4
# información:1
# podría:3
# venir:1
# content:3
# reset:1
# contenido:2
# requiere:3
# requester:2
# recargue:1
# partial:1
# sólo:2
# parte:4
# recurso:10
# debido:1
# limitación:1
# configurado:1
# usa:2
# herramientas:1
# descarga:1
# comowget:1
# mensaje:1
# xml:1
# contener:1
# número:2
# unaexplicación:1
# igualmente:1
# aplican:1
# internal:1
# server:2
# genérico:1
# dado:1
# condición:1
# esperada:1
# concretar:1
# implemented:1
# reconoce:1
# elmétodo:1
# requesto:1
# carece:1
# capacidad:1
# completarlo:1
# normalmente:1
# ofrecerá:1
# unnuevo:1
# serviciode:1
# gateway:2
# actuaba:1
# puerta:1
# entrada:1
# oproxyy:1
# recibió:2
# inválida:1
# service:1
# unavailable:1
# actualmente:1
# pormantenimientoo:1
# actuando:1
# comopuerta:1
# entradaoproxyy:1
# oportuna:1
# version:1
# supported:1
# soporta:1
# laversión:1
# protocolo:1
# httpusada:1
# network:1
# necesita:1
# autentificarse:1
# poder:1
# acceder:1
# lázaro:1
# construido:1
# consymfony:1

# %%
#Visualizar Tokens
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
freq_clean.plot(30, cumulative=False)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# # 3a. Obtener Sinónimos

# %%
from nltk.corpus import wordnet
 
synonyms = []
 
for syn in wordnet.synsets('error'):

    for lemma in syn.lemmas():
 
        synonyms.append(lemma.name())
 
print(synonyms)
# Out:
# ['mistake', 'error', 'fault', 'erroneousness', 'error', 'error', 'erroneous_belief', 'error', 'misplay', 'error', 'wrongdoing', 'error', 'computer_error', 'error', 'mistake']

# %%
#Reemplazar tokens sinónimos
for ind,sin in enumerate(synonyms):
    clean_tokens_sin = [word.replace(synonyms[ind],'error') for word in clean_tokens]

# %%
#Reemplazar tokens sinónimos manual
sinonimos = ['libertad', 'independencia']
for ind,sin in enumerate(sinonimos):
    clean_tokens_sin = [word.replace(sinonimos[ind],'libertad') for word in clean_tokens]

# %%
#Recalcular frecuencia de palabras con sinónimos agregados
freq_clean_sin = nltk.FreqDist(clean_tokens_sin)
for key,val in freq_clean_sin.items():
    print (str(key) + ':' + str(val))
# Out:
# códigos:8
# http:9
# function:1
# i:6
# s:1
# g:1
# r:6
# m:2
# arguments:1
# new:1
# date:1
# window:1
# document:1
# ga:2
# diego:2
# lázaroangularlibro:1
# phpinicioangulardiego:1
# lázarocontactoangularlibro:1
# phpcódigos:1
# httpcódigos:1
# respuestas:5
# servidor:22
# puede:9
# devolver:1
# recibe:1
# petición:2
# requestcontenido:1
# modificablesi:1
# ves:1
# errores:5
# quieres:1
# contenidos:1
# puedescrear:1
# pull:1
# request:27
# graciaslos:1
# describen:1
# forma:1
# abreviada:1
# larespuesta:1
# especificados:1
# elrfc:1
# primer:1
# dígito:1
# código:5
# especifica:2
# tipos:1
# respuesta:7
# mínimo:1
# cliente:10
# pueda:1
# trabajar:1
# conhttpes:1
# reconozca:1
# clases:1
# lainternet:1
# assigned:1
# numbers:1
# authority:1
# iana:1
# mantiene:1
# registro:1
# oficial:1
# peticiones:3
# informativaseste:1
# tipo:1
# indica:4
# unarespuesta:1
# provisional:1
# definió:1
# ningún:3
# servidores:2
# deberían:2
# enviar:2
# salvo:2
# continue:1
# recibido:1
# losheaders:1
# requesty:1
# debería:4
# proceder:1
# cuerpo:2
# switching:1
# protocols:1
# elrequesterha:1
# solicitado:5
# conmutar:1
# processing:1
# webdav:2
# rfc:10
# usado:1
# enrequestspara:1
# reanudar:1
# put:1
# post:3
# correctaseste:1
# añade:1
# entity:1
# too:2
# large:1
# largo:2
# dispuesto:1
# aceptar:1
# long:1
# eluries:1
# unsupported:1
# media:1
# type:1
# unmedia:1
# typeque:1
# requested:1
# range:1
# satisfiable:1
# porción:1
# archivo:1
# ofrecer:1
# expectation:1
# cumplir:1
# requerimientos:1
# header:1
# teapot:1
# unapril:1
# fool:1
# day:1
# espera:1
# implemente:1
# ser:1
# devuelto:1
# teteras:1
# servir:1
# servidorel:1
# aparentemente:1
# válida:1
# empiezan:1
# casos:1
# queel:1
# sabe:1
# erroro:1
# realmente:1
# esincapaz:1
# trata:1
# requesthead:1
# conteniendo:1
# unaexplicación:1
# igualmente:1
# aplican:1
# internal:1
# server:2
# genérico:1
# dado:1
# condición:1
# esperada:1
# concretar:1
# implemented:1
# reconoce:1
# elmétodo:1
# requesto:1
# carece:1
# capacidad:1
# completarlo:1
# normalmente:1
# ofrecerá:1
# unnuevo:1
# serviciode:1
# gateway:2
# actuaba:1
# puerta:1
# entrada:1
# oproxyy:1
# recibió:2
# inválida:1
# service:1
# unavailable:1
# actualmente:1
# pormantenimientoo:1
# actuando:1
# comopuerta:1
# entradaoproxyy:1
# oportuna:1
# version:1
# supported:1
# soporta:1
# laversión:1
# protocolo:1
# httpusada:1
# network:1
# necesita:1
# autentificarse:1
# poder:1
# acceder:1
# lázaro:1
# construido:1
# consymfony:1

# %%
#Visualizar Tokens
freq_clean_sin.plot(30, cumulative=False)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# # 3b. Obtener Antónimos

# %%
from nltk.corpus import wordnet
 
antonyms = []
 
for syn in wordnet.synsets("good"):
 
    for l in syn.lemmas():
 
        if l.antonyms():
 
            antonyms.append(l.antonyms()[0].name())
 
print(antonyms)
# Out:
# ['evil', 'evilness', 'bad', 'badness', 'bad', 'evil', 'ill']

# %% [markdown]
# # 4. Derivación Regresiva

# %%
from nltk.stem import PorterStemmer
 
stemmer = PorterStemmer()
 
print(stemmer.stem('eating'))
# Out:
# eat

# %%
#Derivación regresiva textos en español
from nltk.stem import SnowballStemmer
 
spanish_stemmer = SnowballStemmer('spanish')
 
print(spanish_stemmer.stem("trabajando"))
print(spanish_stemmer.stem("trabajo"))
# Out:
# trabaj
# trabaj

# %%
clean_tokens_sin_stems = [spanish_stemmer.stem(token) for token in clean_tokens_sin]

# %%
clean_tokens_sin_stems
# Out:
# ['codig',
#  'http',
#  'function',
#  'i',
#  's',
#  'g',
#  'r',
#  'm',
#  'i',
#  'i',
#  'r',
#  'r',
#  'i',
#  'r',
#  'r',
#  'arguments',
#  'i',
#  'r',
#  'new',
#  'dat',
#  'm',
#  'window',
#  'document',
#  'ga',
#  'ga',
#  'dieg',
#  'lazaroangularlibr',
#  'phpinicioangulardieg',
#  'lazarocontactoangularlibr',
#  'phpcodig',
#  'httpcodig',
#  'respuest',
#  'http',
#  'servidor',
#  'pued',
#  'devolv',
#  'recib',
#  'peticion',
#  'http',
#  'requestconten',
#  'modificablesi',
#  'ves',
#  'error',
#  'quier',
#  'conten',
#  'puedescr',
#  'pull',
#  'request',
#  'graciasl',
#  'codig',
#  'http',
#  'describ',
#  'form',
#  'abrevi',
#  'larespuest',
#  'http',
#  'codig',
#  'especific',
#  'elrfc',
#  'prim',
#  'digit',
#  'codig',
#  'especif',
#  'tip',
#  'respuest',
#  'minim',
#  'client',
#  'pued',
#  'trabaj',
#  'conhttp',
#  'reconozc',
#  'clas',
#  'lainternet',
#  'assign',
#  'numbers',
#  'authority',
#  'ian',
#  'mantien',
#  'registr',
#  'oficial',
#  'codig',
#  'respuest',
#  'peticion',
#  'error',
#  'error',
#  'respuest',
#  'informativasest',
#  'tip',
#  'codig',
#  'indic',
#  'unarespuest',
#  'provisional',
#  'defin',
#  'ningun',
#  'servidor',
#  'deb',
#  'envi',
#  'respuest',
#  'client',
#  'salv',
#  'continu',
#  'servidor',
#  'recib',
#  'losheaders',
#  'requesty',
#  'client',
#  'deb',
#  'proced',
#  'envi',
#  'cuerp',
#  'switching',
#  'protocols',
#  'elrequesterh',
#  'solicit',
#  'servidor',
#  'conmut',
#  'processing',
#  'webdav',
#  'rfc',
#  'usad',
#  'enrequestsp',
#  'reanud',
#  'peticion',
#  'put',
#  'post',
#  'peticion',
#  'correctasest',
#  'codig',
#  'indic',
#  'accion',
#  'solicit',
#  'elclienteh',
#  'sid',
#  'recib',
#  'entend',
#  'acept',
#  'proces',
#  'ok',
#  'request',
#  'correct',
#  'respuest',
#  'estand',
#  'respuest',
#  'creat',
#  'request',
#  'complet',
#  'cre',
#  'nuev',
#  'acept',
#  'request',
#  'acept',
#  'proces',
#  'proces',
#  'aun',
#  'information',
#  'request',
#  'proces',
#  'correct',
#  'devuelv',
#  'inform',
#  'podr',
#  'ven',
#  'content',
#  'request',
#  'proces',
#  'correct',
#  'devuelv',
#  'ningun',
#  'reset',
#  'content',
#  'request',
#  'proces',
#  'correct',
#  'devuelv',
#  'ningun',
#  'conten',
#  'requier',
#  'request',
#  'recarg',
#  'partial',
#  'content',
#  'servidor',
#  'devuelv',
#  'sol',
#  'part',
#  'recurs',
#  'deb',
#  'limit',
#  'configur',
#  'client',
#  'usa',
#  'herramient',
#  'descarg',
#  'comowget',
#  'webdav',
#  'rfc',
#  'cuerp',
#  'mensaj',
#  'xml',
#  'pued',
#  'conten',
#  'numer',
#  'codig',
#  'diferent',
#  'depend',
#  'numer',
#  'redireccionesel',
#  'client',
#  'tom',
#  'accion',
#  'adicional',
#  'complet',
#  'elrequest',
#  'utiliz',
#  'pararedireccion',
#  'llev',
#  'cab',
#  'accion',
#  'adicional',
#  'neces',
#  'actu',
#  'elusuariosol',
#  'si',
#  'elmetodoutiliz',
#  'segund',
#  'peticion',
#  'esgetoh',
#  'deb',
#  'redireccion',
#  'automat',
#  'request',
#  'cinc',
#  'vec',
#  'redireccion',
#  'suel',
#  'indic',
#  'uninfinit',
#  'multipl',
#  'choic',
#  'list',
#  'enlac',
#  'usuari',
#  'pued',
#  'seleccion',
#  'enlac',
#  'ir',
#  'direccion',
#  'maxim',
#  'cinc',
#  'mov',
#  'permanently',
#  'pagin',
#  'solicit',
#  'mov',
#  'permanent',
#  'nuev',
#  'found',
#  'pagin',
#  'solicit',
#  'mov',
#  'temporal',
#  'nuev',
#  'see',
#  'other',
#  'pagin',
#  'solicit',
#  'pued',
#  'encontr',
#  'uri',
#  'not',
#  'modifi',
#  'indic',
#  'pagin',
#  'solicit',
#  'modific',
#  'ultim',
#  'use',
#  'proxy',
#  'recurs',
#  'solicit',
#  'sol',
#  'dispon',
#  'traves',
#  'proxy',
#  'cuy',
#  'direccion',
#  'proporcion',
#  'respuest',
#  'client',
#  'http',
#  'mozill',
#  'internet',
#  'explor',
#  'manej',
#  'bien',
#  'respuest',
#  'codig',
#  'temporary',
#  'redirect',
#  'pagin',
#  'solicit',
#  'mov',
#  'temporal',
#  'url',
#  'cas',
#  'recurs',
#  'deb',
#  'repet',
#  'uri',
#  'embarg',
#  'futur',
#  'requests',
#  'deb',
#  'usar',
#  'uri',
#  'original',
#  'contrari',
#  'metod',
#  'request',
#  'pued',
#  'cambi',
#  'reubiqu',
#  'request',
#  'permanent',
#  'redirect',
#  'rfc',
#  'request',
#  'futur',
#  'requests',
#  'deb',
#  'repet',
#  'usand',
#  'uri',
#  'simil',
#  'permit',
#  'metod',
#  'http',
#  'error',
#  'clienteexcept',
#  'respond',
#  'unhe',
#  'request',
#  'servidor',
#  'deb',
#  'inclu',
#  'entid',
#  'contien',
#  'explic',
#  'error',
#  'si',
#  'temporal',
#  'permanent',
#  'aplic',
#  'cualqui',
#  'metod',
#  'solicitud',
#  'get',
#  'post',
#  'losus',
#  'agentsdeb',
#  'mostr',
#  'cualqui',
#  'entid',
#  'bad',
#  'request',
#  'servidor',
#  'pued',
#  'va',
#  'proces',
#  'request',
#  'error',
#  'sintaxis',
#  'unauthoriz',
#  'rfc',
#  'simil',
#  'error',
#  'usa',
#  'requier',
#  'autentif',
#  'fall',
#  'todav',
#  'payment',
#  'requir',
#  'reserv',
#  'futur',
#  'uso',
#  'intencion',
#  'original',
#  'parapag',
#  'tarjetaomicropag',
#  'ocurr',
#  'codig',
#  'apen',
#  'forbidd',
#  'request',
#  'val',
#  'peroel',
#  'servidor',
#  'nieg',
#  'not',
#  'found',
#  'recurs',
#  'request',
#  'pod',
#  'encontr',
#  'podr',
#  'dispon',
#  'futur',
#  'permitenrequests',
#  'subsecuentespor',
#  'part',
#  'method',
#  'not',
#  'allow',
#  'hech',
#  'request',
#  'recurs',
#  'usand',
#  'unmetod',
#  'request',
#  'soportadopor',
#  'recurs',
#  'ejempl',
#  'usand',
#  'get',
#  'formulari',
#  'requier',
#  'post',
#  'not',
#  'accept',
#  'recurs',
#  'solicit',
#  'sol',
#  'generaconten',
#  'aceptadod',
#  'acuerd',
#  'headers',
#  'accept',
#  'envi',
#  'proxy',
#  'authentication',
#  'requir',
#  'rfc',
#  'client',
#  'deb',
#  'identific',
#  'primer',
#  'request',
#  'timeout',
#  'client',
#  'envi',
#  'unrequest',
#  'tiemp',
#  'necesariocon',
#  'servidor',
#  'prepar',
#  'esper',
#  'client',
#  'podr',
#  'repet',
#  'request',
#  'modif',
#  'conflict',
#  'conflict',
#  'request',
#  'actualiz',
#  'mism',
#  'tiemp',
#  'dos',
#  'gon',
#  'recurs',
#  'solicit',
#  'dispon',
#  'buscador',
#  'elimin',
#  'pagin',
#  'length',
#  'requir',
#  'request',
#  'especific',
#  'lalongitud',
#  'conten',
#  'requer',
#  'recurs',
#  'precondition',
#  'fail',
#  'rfc',
#  'servidor',
#  'cumpl',
#  'precondicion',
#  'request',
#  'añad',
#  'request',
#  'entity',
#  'too',
#  'larg',
#  'request',
#  'larg',
#  'dispuest',
#  'acept',
#  'too',
#  'long',
#  'eluri',
#  'larg',
#  'servidor',
#  'unsupport',
#  'medi',
#  'type',
#  'entid',
#  'request',
#  'unmedi',
#  'typequ',
#  'servidor',
#  'recurs',
#  'request',
#  'rang',
#  'not',
#  'satisfi',
#  'rfc',
#  'client',
#  'solicit',
#  'porcion',
#  'archiv',
#  'servidor',
#  'pued',
#  'ofrec',
#  'expectation',
#  'fail',
#  'servidor',
#  'pued',
#  'cumpl',
#  'requer',
#  'head',
#  'request',
#  'i',
#  'teapot',
#  'rfc',
#  'part',
#  'unapril',
#  'fool',
#  'day',
#  'esper',
#  'implement',
#  'servidor',
#  'http',
#  'rfc',
#  'especif',
#  'codig',
#  'deb',
#  'ser',
#  'devuelt',
#  'teter',
#  'serv',
#  'error',
#  'servidorel',
#  'servidor',
#  'fall',
#  'complet',
#  'solicitud',
#  'aparent',
#  'val',
#  'codig',
#  'empiez',
#  'indic',
#  'cas',
#  'queel',
#  'servidor',
#  'sab',
#  'error',
#  'realment',
#  'esincapaz',
#  'proces',
#  'request',
#  'salv',
#  'trat',
#  'requesth',
#  'servidor',
#  'deb',
#  'inclu',
#  'entid',
#  'conten',
#  'unaexpl',
#  'error',
#  'si',
#  'temporal',
#  'permanent',
#  'igual',
#  'deb',
#  'mostr',
#  'cualqui',
#  'entid',
#  'usuari',
#  'codig',
#  'respuest',
#  'aplic',
#  'cualqui',
#  'metod',
#  'internal',
#  'serv',
#  'error',
#  'error',
#  'gener',
#  'dad',
#  'condicion',
#  'esper',
#  'pued',
#  'concret',
#  'not',
#  'implement',
#  'servidor',
#  'reconoc',
#  'elmetod',
#  'request',
#  'carec',
#  'capac',
#  'complet',
#  'normal',
#  'ofrec',
#  'futur',
#  'unnuev',
#  'serviciod',
#  'bad',
#  'gateway',
#  'serv',
#  'actu',
#  'puert',
#  'entrad',
#  'oproxyy',
#  'recib',
#  'respuest',
#  'inval',
#  'servidor',
#  'servic',
#  'unavail',
#  'servidor',
#  'actual',
#  'dispon',
#  'pormantenimiento',
#  'gateway',
#  'timeout',
#  'servidor',
#  'actu',
#  'comopuert',
#  'entradaoproxyy',
#  'recib',
#  'respuest',
#  'oportun',
#  'part',
#  'servidor',
#  'http',
#  'version',
#  'not',
#  'support',
#  'servidor',
#  'soport',
#  'laversion',
#  'protocol',
#  'httpus',
#  'network',
#  'authentication',
#  'requir',
#  'rfc',
#  'client',
#  'necesit',
#  'autentific',
#  'pod',
#  'acced',
#  'dieg',
#  'lazar',
#  'constru',
#  'consymfony']

# %%
# Recalcular frecuencia de palabras con sinónimos agregados
freq_clean_sin
# va:1
# sintaxis:1
# unauthoriz:1
# autentif:1
# fall:2
# todav:1
# payment:1
# requir:4
# reserv:1
# uso:1
# intencion:1
# parapag:1
# tarjetaomicropag:1
# ocurr:1
# apen:1
# forbidd:1
# val:2
# peroel:1
# nieg:1
# pod:2
# permitenrequests:1
# subsecuentespor:1
# method:1
# allow:1
# hech:1
# unmetod:1
# soportadopor:1
# ejempl:1
# formulari:1
# accept:2
# generaconten:1
# aceptadod:1
# acuerd:1
# headers:1
# authentication:2
# identific:1
# primer:1
# timeout:2
# unrequest:1
# tiemp:2
# necesariocon:1
# prepar:1
# esper:3
# modif:1
# conflict:2
# actualiz:1
# mism:1
# dos:1
# gon:1
# buscador:1
# elimin:1
# length:1
# lalongitud:1
# requer:2
# precondition:1
# fail:2
# cumpl:2
# precondicion:1
# añad:1
# entity:1
# too:2
# larg:3
# dispuest:1
# long:1
# eluri:1
# unsupport:1
# medi:1
# type:1
# unmedi:1
# typequ:1
# rang:1
# satisfi:1
# porcion:1
# archiv:1
# ofrec:2
# expectation:1
# head:1
# teapot:1
# unapril:1
# fool:1
# day:1
# implement:2
# ser:1
# devuelt:1
# teter:1
# serv:3
# servidorel:1
# aparent:1
# empiez:1
# queel:1
# sab:1
# realment:1
# esincapaz:1
# trat:1
# requesth:1
# unaexpl:1
# igual:1
# internal:1
# gener:1
# dad:1
# condicion:1
# concret:1
# reconoc:1
# elmetod:1
# carec:1
# capac:1
# normal:1
# unnuev:1
# serviciod:1
# gateway:2
# puert:1
# entrad:1
# oproxyy:1
# inval:1
# servic:1
# unavail:1
# actual:1
# pormantenimiento:1
# comopuert:1
# entradaoproxyy:1
# oportun:1
# version:1
# support:1
# soport:1
# laversion:1
# protocol:1
# httpus:1
# network:1
# necesit:1
# autentific:1
# acced:1
# lazar:1
# constru:1
# consymfony:1
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# # 5. Lematizar palabras

# %%
from nltk.stem import WordNetLemmatizer
 
lemmatizer = WordNetLemmatizer()
 
print(lemmatizer.lemmatize('working', pos="v")) #sustantivos de manera predeterminada, especificar "v" si se quieren los verbos
# Out:
# work

# %%
#Alternativa para texto en español --- Instalar spicy: pip install spicy
import spacy
nlp = spacy.blank('es')

# %%
#Lematizar tokens tras limpieza y convertidos los sinónimos
clean_tokens_sin_lem = []
separator = ' '
for token in nlp(separator.join(clean_tokens_sin)): #Se juntan los tokens en una string, string es el formato necesario para nlp
    print(token.text, token.lemma_, token.pos_)
    clean_tokens_sin_lem.append(token.lemma_)
# Out:
# códigos
# http
# function
# i
# s
# g
# r
# m
# i
# i
# r
# r
# i
# r
# r
# arguments
# i
# r
# new
# date
# m
# window
# document
# ga
# ga
# diego
# lázaroangularlibro
# phpinicioangulardiego
# lázarocontactoangularlibro
# phpcódigos
# httpcódigos
# respuestas
# http
# servidor
# puede
# devolver
# recibe
# petición
# http
# requestcontenido
# modificablesi
# ves
# errores
# quieres
# contenidos
# puedescrear
# pull
# request
# graciaslos
# códigos
# http
# describen
# forma
# abreviada
# larespuesta
# http
# códigos
# especificados
# elrfc
# primer
# dígito
# código
# especifica
# tipos
# respuesta
# mínimo
# cliente
# pueda
# trabajar
# conhttpes
# reconozca
# clases
# lainternet
# assigned
# numbers
# authority
# iana
# mantiene
# registro
# oficial
# códigos
# respuestas
# peticiones
# errores
# errores
# respuestas
# informativaseste
# tipo
# código
# indica
# unarespuesta
# provisional
# definió
# ningún
# servidores
# deberían
# enviar
# respuesta
# cliente
# salvo
# continue
# servidor
# recibido
# losheaders
# requesty
# cliente
# debería
# proceder
# enviar
# cuerpo
# switching
# protocols
# elrequesterha
# solicitado
# servidor
# conmutar
# processing
# webdav
# rfc
# usado
# enrequestspara
# reanudar
# peticiones
# put
# post
# peticiones
# correctaseste
# código
# indica
# acción
# solicitada
# elclienteha
# sido
# recibida
# entendida
# aceptada
# procesada
# ok
# request
# correcto
# respuesta
# estándar
# respuestas
# created
# request
# completado
# creado
# nuevo
# aceptada
# request
# aceptado
# procesarlo
# proceso
# aún
# information
# request
# procesado
# correctamente
# devuelve
# información
# podría
# venir
# content
# request
# procesado
# correctamente
# devuelve
# ningún
# reset
# content
# request
# procesado
# correctamente
# devuelve
# ningún
# contenido
# requiere
# requester
# recargue
# partial
# content
# servidor
# devuelve
# sólo
# parte
# recurso
# debido
# limitación
# configurado
# cliente
# usa
# herramientas
# descarga
# comowget
# webdav
# rfc
# cuerpo
# mensaje
# xml
# puede
# contener
# número
# códigos
# diferentes
# dependiendo
# número
# redireccionesel
# cliente
# tomar
# acción
# adicional
# completar
# elrequest
# utilizan
# pararedirecciones
# llevar
# cabo
# acción
# adicional
# necesidad
# actúe
# elusuariosólo
# si
# elmétodoutilizado
# segunda
# petición
# esgetohead
# debería
# redireccionar
# automáticamente
# request
# cinco
# veces
# redirecciones
# suelen
# indicar
# uninfinite
# multiple
# choices
# lista
# enlaces
# usuario
# puede
# seleccionar
# enlace
# ir
# dirección
# máximo
# cinco
# moved
# permanently
# página
# solicitada
# movido
# permanentemente
# nueva
# found
# página
# solicitada
# movido
# temporalmente
# nueva
# see
# other
# página
# solicitada
# puede
# encontrar
# uri
# not
# modified
# indica
# página
# solicitada
# modificado
# última
# use
# proxy
# recurso
# solicitado
# sólo
# disponible
# través
# proxy
# cuya
# dirección
# proporciona
# respuesta
# clientes
# http
# mozilla
# internet
# explorer
# manejan
# bien
# respuestas
# códigos
# temporary
# redirect
# página
# solicitada
# movido
# temporalmente
# url
# caso
# recurso
# debería
# repetirse
# uri
# embargo
# futuros
# requests
# deberán
# usar
# uri
# original
# contrario
# método
# request
# puede
# cambiar
# reubique
# request
# permanent
# redirect
# rfc
# request
# futuros
# requests
# deberían
# repetirse
# usando
# uri
# similar
# permite
# método
# http
# errores
# clienteexcepto
# responde
# unhead
# request
# servidor
# debe
# incluir
# entidad
# contiene
# explicación
# error
# si
# temporal
# permanente
# aplicables
# cualquier
# método
# solicitud
# get
# post
# losuser
# agentsdeben
# mostrar
# cualquier
# entidad
# bad
# request
# servidor
# puede
# va
# procesar
# request
# error
# sintaxis
# unauthorized
# rfc
# similar
# error
# usa
# requiere
# autentificación
# fallado
# todavía
# payment
# required
# reservado
# futuro
# uso
# intención
# original
# parapago
# tarjetaomicropago
# ocurrido
# código
# apenas
# forbidden
# request
# válido
# peroel
# servidor
# niega
# not
# found
# recurso
# request
# podido
# encontrar
# podría
# disponible
# futuro
# permitenrequests
# subsecuentespor
# parte
# method
# not
# allowed
# hecho
# request
# recurso
# usando
# unmétodo
# request
# soportadopor
# recurso
# ejemplo
# usando
# get
# formulario
# requiere
# post
# not
# acceptable
# recurso
# solicitado
# solo
# generacontenido
# aceptadode
# acuerdo
# headers
# accept
# enviados
# proxy
# authentication
# required
# rfc
# cliente
# debe
# identificar
# primero
# request
# timeout
# cliente
# enviado
# unrequest
# tiempo
# necesariocon
# servidor
# preparado
# esperar
# cliente
# podría
# repetir
# request
# modificaciones
# conflict
# conflicto
# request
# actualizan
# mismo
# tiempo
# dos
# gone
# recurso
# solicitado
# disponible
# buscador
# eliminará
# página
# length
# required
# request
# especificó
# lalongitud
# contenido
# requerida
# recurso
# precondition
# failed
# rfc
# servidor
# cumple
# precondiciones
# requester
# añade
# request
# entity
# too
# large
# request
# largo
# dispuesto
# aceptar
# too
# long
# eluries
# largo
# servidor
# unsupported
# media
# type
# entidad
# request
# unmedia
# typeque
# servidor
# recurso
# requested
# range
# not
# satisfiable
# rfc
# cliente
# solicitado
# porción
# archivo
# servidor
# puede
# ofrecer
# expectation
# failed
# servidor
# puede
# cumplir
# requerimientos
# header
# request
# i
# teapot
# rfc
# parte
# unapril
# fool
# day
# espera
# implemente
# servidores
# http
# rfc
# especifica
# código
# debería
# ser
# devuelto
# teteras
# servir
# errores
# servidorel
# servidor
# fallado
# completar
# solicitud
# aparentemente
# válida
# códigos
# empiezan
# indica
# casos
# queel
# servidor
# sabe
# erroro
# realmente
# esincapaz
# procesar
# request
# salvo
# trata
# requesthead
# servidor
# debe
# incluir
# entidad
# conteniendo
# unaexplicación
# error
# si
# temporal
# permanente
# igualmente
# deberán
# mostrar
# cualquier
# entidad
# usuario
# códigos
# respuesta
# aplican
# cualquier
# método
# internal
# server
# error
# error
# genérico
# dado
# condición
# esperada
# puede
# concretar
# not
# implemented
# servidor
# reconoce
# elmétodo
# requesto
# carece
# capacidad
# completarlo
# normalmente
# ofrecerá
# futuro
# unnuevo
# serviciode
# bad
# gateway
# server
# actuaba
# puerta
# entrada
# oproxyy
# recibió
# respuesta
# inválida
# servidor
# service
# unavailable
# servidor
# actualmente
# disponible
# pormantenimientoo
# gateway
# timeout
# servidor
# actuando
# comopuerta
# entradaoproxyy
# recibió
# respuesta
# oportuna
# parte
# servidor
# http
# version
# not
# supported
# servidor
# soporta
# laversión
# protocolo
# httpusada
# network
# authentication
# required
# rfc
# cliente
# necesita
# autentificarse
# poder
# acceder
# diego
# lázaro
# construido
# consymfony

# %%
# Recalcular frecuencia de palabras con sinónimos agregados
freq_clean_sin_lem = nltk.FreqDist(clean_tokens_sin_lem)
for key,val in freq_clean_sin_lem.items():
    print (str(key) + ':' + str(val))
    
#Visualizar Tokens
freq_clean_sin_lem.plot(30, cumulative=False)
# Out:
# :671
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>
